# %%
import requests
import json
# Replace YOUR_API_KEY with your actual API key
api_key = 'jf8cbNa7EMty2rmJHor6cxcrTGV1xrtuSWz0Cm5S'

# %%
# define parameters for API request
state_abbr = 'AL' # state abbreviation (e.g., AL for Alabama)
county_code = '001' # three-digit FIPS county code (e.g., 001 for Autauga County, AL)
series_id = f'SEDS.TETCB.{state_abbr}.{county_code}.M' # total energy consumption by month and county
start_year = '2010'
end_year = '2020'

# build URL for API request
url = f'https://api.eia.gov/series/?api_key={api_key}&series_id={series_id}&start={start_year}0101&end={end_year}1231'

# make API request and parse JSON response
response = requests.get(url)
data = json.loads(response.content)

# # extract energy consumption data by month and year
# months = data['series'][0]['data']
# for month in months:
#     date = month[0] # date in format YYYYMM
#     year = date[:4]
#     month_num = date[4:]
#     consumption = month[1]
#     print(f'{year}-{month_num}: {consumption} MMBtu')

# %%
import requests

url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/data/"

params = {
    "frequency": "monthly",
    "data": [
        "total-consumption"
    ],
    "facets": {
        "fueltypeid": [
            "COW"
        ],
        "sectorid": [
            99
        ],
        "location": [
            "AK",
            "AL",
            "AR",
            "AZ",
            "CA",
            "CO",
            "CT",
            "DE",
            "ENC",
            "ESC",
            "FL",
            "GA",
            "HI",
            "IA",
            "ID",
            "IL",
            "IN",
            "KS",
            "KY",
            "LA",
            "MA",
            "MAT",
            "MD",
            "ME",
            "MI",
            "MN",
            "MO",
            "MS",
            "MT",
            "MTN",
            "NC",
            "ND",
            "NE",
            "NEW",
            "NH",
            "NJ",
            "NM",
            "NV",
            "NY",
            "OH",
            "OK",
            "PA",
            "PCC",
            "PCN",
            "RI",
            "SC",
            "SD",
            "TN",
            "TX",
            "UT",
            "VA",
            "WA",
            "WI",
            "WNC",
            "WSC",
            "WV",
            "WY"
        ]
    },
    "start": "2021-01",
    "end": "2023-01",
    "sort": [
        {
            "column": "period",
            "direction": "desc"
        }
    ],
    "offset": 0,
    "length": 5000
}

headers = {
    "X-Api-Key": api_key
}

response = requests.get(url, params=params, headers=headers)

print(response.content)
# Out:
# b'{"error":"Invalid format for facet \'location\'. Must provide which facet and an array of values. For example, to filter by location for VA and CA: facets[location][]=VA&facets[location][]=CA","code":400}'

# %%
print(response.content)
print(response.headers)
# Out:
# b'{"error":"Invalid format for facet \'location\'. Must provide which facet and an array of values. For example, to filter by location for VA and CA: facets[location][]=VA&facets[location][]=CA","code":400}'
# ...

# %%
dt = data[data['lat'].notnull()]

# %%
d = dt['name'].drop_duplicates()

# %%
dt
# Out:
#                                  series_id  \
# 0        ELEC.PLANT.CONS_EG.57208-DFO-IC.Q
# 1        ELEC.PLANT.CONS_EG.57241-NG-ALL.A
# 2       ELEC.PLANT.CONS_EG.57343-OBG-ALL.Q
# 3        ELEC.PLANT.CONS_EG.57343-OBG-IC.A
# 4        ELEC.PLANT.CONS_EG.57343-OBG-IC.M
# ...                                    ...
# 683237   ELEC.PLANT.CONS_TOT.58176-NG-ST.Q
# 683238   ELEC.PLANT.CONS_TOT.58427-NG-GT.A
# 683239   ELEC.PLANT.CONS_TOT.58427-NG-GT.M
# 683240   ELEC.PLANT.CONS_TOT.58427-NG-GT.Q
# 683241   ELEC.PLANT.CONS_TOT.58427-NG-ST.A
#
#                                                      name    units  f  \
# 0       Electric fuel consumption quantity : Thomson R...  barrels  Q
# 1       Electric fuel consumption quantity : Deerhaven...      mcf  A
# 2       Electric fuel consumption quantity : Cargill B...      mcf  Q
# 3       Electric fuel consumption quantity : Cargill B...      mcf  A
# 4       Electric fuel consumption quantity : Cargill B...      mcf  M
# ...

# %%
len(dt)
# Out:
# 594581

# %%
import requests
import json
import prettytable
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CN0100','SUUR0000SA0'],"startyear":"2011", "endyear":"2023"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
print(pd.json_normalize(json_data))
# for series in json_data['Results']['series']:
#     x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
#     seriesId = series['seriesID']
#     for item in series['data']:
#         year = item['year']
#         period = item['period']
#         value = item['value']
#         footnotes=""
#         for footnote in item['footnotes']:
#             if footnote:
#                 footnotes = footnotes + footnote['text'] + ','
#         if 'M01' <= period <= 'M12':
#             x.add_row([seriesId,year,period,value,footnotes[0:-1]])
#     output = open(seriesId + '.txt','w')
#     output.write (x.get_string())
#     output.close()
# Out:
#               status  responseTime  \
# 0  REQUEST_SUCCEEDED           348
#
#                                              message  \
# 0  [Year range has been reduced to the system-all...
#
#                                       Results.series
# 0  [{'seriesID': 'CN0100', 'data': []}, {'seriesI...

# %%
import pandas as pd
df = pd.read_csv('CUUR0000SA0.txt', header=1)

# %%
df.iloc[1:]
# Out:
#    |  series id  | year | period |  value  | footnotes |
# 1   | CUUR0000SA0 | 2014 |  M12   | 234.812 |     ...
# 2   | CUUR0000SA0 | 2014 |  M11   | 236.151 |     ...
# 3   | CUUR0000SA0 | 2014 |  M10   | 237.433 |     ...
# 4   | CUUR0000SA0 | 2014 |  M09   | 238.031 |     ...
# 5   | CUUR0000SA0 | 2014 |  M08   | 237.852 |     ...
# 6   | CUUR0000SA0 | 2014 |  M07   | 238.250 |     ...
# 7   | CUUR0000SA0 | 2014 |  M06   | 238.343 |     ...
# 8   | CUUR0000SA0 | 2014 |  M05   | 237.900 |     ...
# 9   | CUUR0000SA0 | 2014 |  M04   | 237.072 |     ...
# 10  | CUUR0000SA0 | 2014 |  M03   | 236.293 |     ...
# 11  | CUUR0000SA0 | 2014 |  M02   | 234.781 |     ...
# 12  | CUUR0000SA0 | 2014 |  M01   | 233.916 |     ...
# 13  | CUUR0000SA0 | 2013 |  M12   | 233.049 |     ...
# 14  | CUUR0000SA0 | 2013 |  M11   | 233.069 |     ...
# 15  | CUUR0000SA0 | 2013 |  M10   | 233.546 |     ...
# 16  | CUUR0000SA0 | 2013 |  M09   | 234.149 |     ...
# ...

# %%
import requests
import pandas as pd
import json
states = ['Arkansas']

for state in states:
    url = f'https://download.bls.gov/pub/time.series/la/la.data.10.{state}'
    r = requests.get(url).text
    
    print(r)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
